# %%
import pandas as pd
df:pd.DataFrame = pd.read_csv("step5.csv")
df
# Out:
#         floor  kitchen_area  living_area  rooms  is_apartment  studio
# 0           9          9.90    19.900000      1             0       0  \
# 1           7          0.00    16.600000      1             0       0
# 2           9          9.00    32.000000      2             0       0
# 3           3          3.00    14.000000      1             0       0
# 4           9          0.00     0.000000      2             0       0
# ...       ...           ...          ...    ...           ...     ...
# 110329      8          6.00    42.000000      3             0       0
# 110330      5          5.28    28.330000      2             0       0
# 110331      7          5.30    20.000000      1             0       0
# 110332     15         13.80    33.700001      2             0       0
# 110333     16          7.60    18.000000      1             0       0
#
#         total_area  build_year  building_type_int   latitude  longitude
# ...

# %%
df.nsmallest(5, "target")
# Out:
#        floor  kitchen_area  living_area  rooms  is_apartment  studio
# 33622      5           6.0          0.0      1             0       0  \
# 67338      3           0.0         30.0      1             0       0
# 61823      3           8.0         55.0      3             0       0
# 47960      8           9.0         26.0      1             0       0
# 62265      8          10.0         16.0      1             0       0
#
#        total_area  build_year  building_type_int   latitude  longitude
# 33622   16.000000        1980                  4  55.618031  37.605957  \
# 67338   35.000000        2019                  2  55.567467  37.490234
# 61823   63.000000        1965                  6  55.681026  37.545979
# 47960   41.000000        1928                  1  55.740913  37.547558
# 62265   39.599998        2016                  2  55.736511  37.412640
#
#        ceiling_height  flats_count  floors_total  has_elevator   target
# ...
